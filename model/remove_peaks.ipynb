# %%
using DataFrames
include("importData.jl")

pop, g2, g1, g1_0, g2_0 = get_data("..//data//lap.csv", "..//data//lap_pop.csv");
# Out:
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, ::Colon, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = get_data(::String, ::String) at importData.jl:31
# └ @ Main /home/farnazm/data/one_state_model/model/importData.jl:31

# %% [markdown]
# #### function 1

# %%
a = g2[:, 7]
aa = remove_peaks(a)
using Plots;
plot(g2[:, 7])
plot!(aa)
